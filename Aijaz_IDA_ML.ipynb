# %% [markdown]
# # Topic = Detecting Defective Lasers
#
# ### Name: Aijaz Afzaal Ahmed
# #### Matr. No.: 821335

# %% [markdown]
# ### **Problem Statement**

# %% [markdown]
# For the purpose of quality assurance, a manufacturer of medical lasers wants to introduce a system which recognizes defective products. For the lasers produced, a constant lightoutput with a frequency as constant as possible is desired. Certain fluctuations are acceptable; Lasers in which the power fluctuates to an intolerable extent should be sorted out. For this purpose, the intensity of each laser is measured for one minute – one measurement per second.

# %% [markdown]
# ### **Aim**

# %% [markdown]
# Classify faulty and non-faulty lasers correctly by implementing different classification models.

# %% [markdown]
# ### **Steps towards Effective and Efficient solution:**

# %% [markdown]
# The following steps are taken for the implementation of the classification models:
#
# **1. Loading Data**
#
# **2. Exploratory Data Analysis (EDA)**
#
# * Insight into the data
#
# * Plot as series
#
# * Mean Values of Fluctuation Points
#
# * Outlier detection
#
# * Histogram-Checking for distribution of features
#
# * Checking Correlations
#
# * Data Normalization
#
#
# **3. Model Implementation**
#
# * Train Test Split
#
# * Used_Models
#
# 1. SVM (Support Vector Machine)
#
# 2. KNN (K Nearest Neighbor)
#
# 3. Decision Tree
#
# 4. Random Forest
#
# **Following these steps to justify all model's robustness:**
#
# * Model training using default parameters
#
# * Generating confusion matrix, classification report and ROC curve
#
# * Applying GridSearchCv for finding best parameters
#
# * Model training using best parameters
#
# * Generating confusion matrix, classification report and ROC curve for comparing with the default parameters
#
#
# **4. Conclusion**

# %%
import numpy as np
import pandas as pd
import scipy.io
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.svm import SVC
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import plot_confusion_matrix
warnings.filterwarnings('ignore')
pd.pandas.set_option('display.max_columns',None)

# %% [markdown]
# # Load Data

# %%
mat = scipy.io.loadmat('laser.mat')
df = pd.DataFrame(np.hstack((mat['X'], mat['Y'])))

# %%
df
# Out:
#           0        1        2        3        4        5        6        7   \
# 0    29.8509  25.7777  28.8859  30.3456  25.2192  26.2419  25.7909  26.3381
# 1    26.2727  31.2289  29.7408  34.2078  33.3289  33.6097  31.0716  22.5296
# 2    34.1790  27.0398  29.3324  31.8299  25.8882  28.2443  33.8510  26.0531
# 3    33.7603  28.0251  27.9612  23.7675  28.7756  29.6775  26.8554  28.2685
# 4    34.7860  27.0130  34.6680  32.1062  33.3359  28.2087  25.1472  24.6253
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 195  32.2096  33.9926  30.6470  30.9754  33.6320  30.5443  25.3864  22.7955
# 196  27.8716  27.0351  28.2645  31.3723  34.9079  24.3547  30.2067  28.6332
# 197  35.8083  31.0808  24.7077  33.2497  27.5799  32.1966  33.5506  25.8530
# 198  33.9818  27.2921  23.2850  31.6800  27.7519  28.2810  22.6567  32.0964
# 199  33.3759  25.4986  31.0451  31.5695  35.6331  33.6964  29.5351  27.6017
#
#           8        9        10       11       12       13       14       15  \
# 0    24.0290  24.1634  28.4092  30.8600  28.9116  28.0824  28.0020  25.5056
# 1    28.5874  21.1298  23.5573  28.0780  27.5457  25.8247  18.4541  25.9026
# 2    31.6576  34.3626  27.1225  30.3713  33.3303  24.2152  28.8840  26.7317
# 3    22.4859  31.5602  22.9522  26.7977  30.9502  29.1207  25.3802  23.6087
# 4    32.8825  30.3093  24.1657  21.3097  28.7224  23.5511  30.3505  28.0259
# ..       ...      ...      ...      ...      ...      ...      ...      ...
#
columns]

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# **Insight into the data**

# %%
x=df.drop(60,axis=1)    
y=df[60]

# %%
plt.style.use('ggplot')
name = ["faulty" if x==-1 else "not-faulty" for x in y]
plt.subplots(figsize = (10,8))
sns.countplot(name)
plt.title("count of the labels")
# Out:
# Text(0.5, 1.0, 'count of the labels')

# %%
missing = np.isnan(df)
fig, ax = plt.subplots(figsize = (10,8))
plt.title("Missing values in each dimension")
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
sns.heatmap(missing, cbar= False)
# Out:
# <AxesSubplot:title={'center':'Missing values in each dimension'}>

# %% [markdown]
# Total number of missing values: 0

# %% [markdown]
# **Plot as series**

# %%
def plot(n, x, y):
  data = np.array(x.values.tolist())
  label = np.array(y.values.tolist())
  fig, axs = plt.subplots(1,n, figsize = (18,8))
  plt.style.use('ggplot')
  for i in range(len(axs)):
    axs[i].plot(np.arange(60), data[i,:], label = label[i])
    axs[i].legend()

# %%
plot(5, x, y)

# %% [markdown]
# **Mean Values of Fluctuation Points**

# %%
names = ["FP"+str(i) for i in range(df.shape[1])]
means = np.mean(df, axis = 0)
plt.figure(figsize = (18,8))
plt.xticks(rotation = 60)
sns.barplot(names, means, palette= 'colorblind')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Outliers detections**

# %%
fig, ax = plt.subplots(10,6, figsize = (18,48))
ax = ax.reshape(-1)
data = np.array(x.values.tolist())
for i in range(60):
  sns.boxplot(data[:,i], ax = ax[i], palette= 'Set1', orient='h')

# %% [markdown]
# Observations from the boxplot:
#
# 1. Some of our features have outliers having a value further from the mean.
# 2. Some outlier values are close to upper whisker so it will have little effect on our classification algorithm.

# %% [markdown]
# **Histogram-Checking for distribution of features**

# %%
fig, ax = plt.subplots(10,6, figsize = (18,48))
ax = ax.reshape(-1)
data = np.array(x.values.tolist())
for i in range(60):
  sns.distplot(data[:,i],  ax = ax[i])

# %% [markdown]
# Using Histogram, we can make an approximation that our attributes are normally distribured with few outliers, hence we can use StandardScaler to scale down our data.
#
# Standard Scaler makes use of the assumption that our features are almost normally ditributed and then scale it by subtracting mean and dividing by standard deviation.

# %% [markdown]
# **Checking Correlations**

# %%
plt.figure(figsize= (10,8))
sns.heatmap(df.corr(),  
            cmap='RdBu_r',
            linewidth=0.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Data Normalization**

# %%
scaler = StandardScaler()
datas = scaler.fit_transform(x)

# %%
normalized_x = pd.DataFrame(datas)
normalized_x
# Out:
#            0         1         2         3         4         5         6   \
# 0   -0.122229 -1.181415 -0.310482  0.321621 -1.175258 -0.854281 -0.890343
# 1   -1.157229  0.395215 -0.050009  1.501718  1.095183  1.242319  0.547019
# 2    1.129680 -0.816383 -0.174441  0.775150 -0.987961 -0.284473  1.303548
# 3    1.008571 -0.531408 -0.592222 -1.688320 -0.179587  0.123362 -0.600595
# 4    1.305256 -0.824134  1.451221  0.859573  1.097143 -0.294604 -1.065552
# ..        ...       ...       ...       ...       ...       ...       ...
# 195  0
# ..        ...       ...       ...       ...       ...       ...       ...
# 106  1.144104  0.277644  1.771754  0.575606  1.297159 -0.080287  0.501612
# 14   1.081545  0.846860  0.220906  1.432345  0.737835  0.804653  1.323236
# 92  -0.178759  1.219806 -0.007704  0.638434 -0.197389  0.437335 -0.383904
# 179  0.196350 -0.942971  0.132869 -0.661178  0.751338  0.017209  0.429877
# 102 -0.333459 -0.102234  1.131057 -0.207383  0.967796  1.542601  0.460917
#
#            42        43        44        45        46        47        48  \
# 169 -0.100732 -1.655437 -0.606618 -0.077382 -0.774954 -1.250301 -0.991761
# 97   1.665959  0.410102  1.618625 -0.065216  1.019491  0.498811  1.242745
# 31   0.387103  0.545950  0.290017 -0.748242  0.126541  0.276077  0.601134
# 12   0.334272 -0.059208  0.936471  1.696428  1.022387  1.291897  0.827062
# 35   4.665255  3.803974  4.955574  4.032631  5.075663  4.742056  3.652186
# ..        ...       ...       ...       ...       ...       ...       ...
# 106  1.638230  0.115208  0.237585  1.162497  0.566071  1.646301  1.982505
# 14   1.510487 -0.062076  1.480448  0.874137  1.725613  0.703536  0.709795
# 92  -0.118092  1.348569  0.785436  1.247081  0.112189  0.076763  1.533632
# 179 -0.723122 -0.911866  0.092675  0.274495 -0.709114  0.044566  0.899425
# 102 -0.084749  0.950419  0.032190  0.750559  0.014049  1.398791  0.584953
#
#            49        50        51        52        53        54        55  \
# 169 -2.038735 -1.796776 -1.297403 -1.095350 -1.383179 -0.998472 -0.807895
# 97   0.724327  0.378804  0.568035  0.409665  0.881427  1.218726  0.864197
# 31  -0.819493 -0.768929 -0.618901 -0.588984  0.878417 -0.128074 -0.471258
# 12   1.411947  0.336168  0.490761  1.902001  2.088233  0.573435  0.801281
# 35   4.870345  3.691612  4.595922  3.371710  4.330867  4.371747  4.871423
# ..        ...       ...       ...       ...       ...       ...       ...
# 106  0.387874  0.398016  1.639887  1.009935  0.623314  0.472227  1.381942
# 14   0.016724  0.746169  0.946413  0.432262  1.362228  1.173538  0.188739
# 92   0.589380  0.410945  1.497158  1.210501  0.032116  0.146328  1.409182
# 179 -0.576247 -0.240308 -0.247983  0.231526  1.069180 -0.475738  0.784931
# 102  0.738125  0.132921  0.189934  1.377935  0.685150  0.723206  0.796654
#
#            56        57        58        59
# 169 -0.778154 -1.954419 -0.621419 -1.914949
# 97   1.174323  0.753100  1.448299  1.163463
# 31  -0.599014  0.150128 -0.485510 -0.215377
# 12   0.963231  1.422217  1.149413  1.432709
# 35   4.601186  3.575356  3.244935  3.893235
# ..        ...       ...       ...       ...
# 106  1.493183  1.059032  1.849043  0.963261
# 14   1.156991  1.259709  1.458522  0.640502
# 92   0.219073  1.300664  0.950071  1.438474
# 179  0.593997 -0.257973  0.456796  0.861532
# 102  0.307003  0.435884  1.261690 -0.136692
#
# [140 rows x 60 columns]

# %% [markdown]
# ### **SVM (Support Vector Machine)**

# %%
classifier_svm = SVC(probability=True)
classifier_svm.fit(X_train, y_train)
# Out:
# SVC(probability=True)

# %%
print(f"accuracy of SVM before hyper-parameter tuning {classifier_svm.score(X_test, y_test)}")
plot_confusion_matrix(classifier_svm,
                      X_test,
                      y_test,
                      display_labels=['Faulty','Fine']
                     )
plt.grid(False)
plt.show()
# Out:
# accuracy of SVM before hyper-parameter tuning 0.9833333333333333

# %%
y_pred = classifier_svm.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#         -1.0       0.97      1.00      0.98        28
#          1.0       1.00      0.97      0.98        32
#
#     accuracy                           0.98        60
#    macro avg       0.98      0.98      0.98        60
# weighted avg       0.98      0.98      0.98        60

# %%
# Examine ROC curve and AUC.
y_hat_proba = classifier_svm.predict_proba(X_test)
svm_fpr, svm_tpr, thresholds2 = roc_curve(y_test, y_hat_proba[:,1])
svm_auc = auc(svm_fpr, svm_tpr)
fig = plt.figure(figsize=(12,7))
ax1 = fig.add_subplot(111)
ax1.fill_between(svm_fpr, svm_tpr, 0, color='Olive', alpha=0.6)
ax1 = plt.plot(svm_fpr, svm_tpr, linewidth=3, label='SVM ROC curve ; AUC = %0.2f' % svm_auc)
plt.legend(loc='upper left')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('SVM ROC Curve before hyper-parameter tuning', size=14)
# Out:
# Text(0.5, 1.0, 'SVM ROC Curve before hyper-parameter tuning')

# %% [markdown]
# **Hyper-parameter tuning for SVM using GridSearchCV**

# %%
parameters = [{'C': [0.1, 0.5, 0.7, 1, 1.5], 'kernel': ['linear']},
              {'C': [0.1, 0.5, 0.7, 1, 1.5], 'kernel': ['rbf','poly'], 'gamma': [0.01, 0.05, 0.1, 0.5]}]
grid_search = GridSearchCV(estimator = classifier_svm,
                           param_grid = parameters,
                           scoring = 'accuracy',
                           cv = 5,
                           n_jobs = -1)
grid_search = grid_search.fit(X_train, y_train)

# %%
grid_search.best_score_
# Out:
# 0.9857142857142858

# %%
grid_search.best_params_
# Out:
# {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}

# %%
cv_results=pd.DataFrame(grid_search.cv_results_)
cv_results=cv_results.sort_values(by='rank_test_score')
cv_results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 29       0.010071      0.000010         0.004429        0.004657       1
# 37       0.011677      0.003210         0.002825        0.003738     1.5
# 21       0.010467      0.000804         0.006044        0.004935     0.7
# 13       0.011677      0.003214         0.002419        0.003906     0.5
# 23       0.012493      0.003891         0.005225        0.004330     0.7
# 39       0.016497      0.003208         0.003633        0.003211     1.5
# 31       0.013696      0.003704         0.004840        0.004336       1
# 15       0.018516      0.003465         0.000404        0.000808     0.5
# 0        0.009704      0.000828         0.002869        0.003821     0.1
# 4        0.009667      0.000807         0.006039        0.003357     1.5
# 3        0.010074      0.000026         0.002429        0.003909       1
# 2        0.011271      0.003507         0.000810        0.000992     0.7
# 1        0.010060      0.000011         0.004037        0.004225     0.5
# 41       0.010875      0.000984         0.008032        0.000004     1.5
# 33       0.013294      0.003525         0.004840        0.003952       1
# 8        0.010483      0.000839         0.002012        0.004024     0.1
# 5        0.016902      0.003938         0.000003        0.000006     0.1
# 16       0.012874      0.004337         0.000809        0.000991     0.5
# 28       0.010871      0.000994         0.003621        0.003683     0.7
# 36       0.011681      0.003216         0.004026        0.003361       1
# 34       0.010896      0.000998         0.003616        0.003677       1
# 40       0.010062      0.000011         0.005635        0.004660     1.5
# 42       0.013279      0.003941         0.000810        0.000992     1.5
# 32       0.010479      0.000826         0.004036        0.004231       1
# 26       0.012480      0.003914         0.003218        0.003941     0.7
# 44       0.010488      0.000806         0.004818        0.003934     1.5
# 24       0.012086      0.003109         0.005224        0.003500     0.7
# 10       0.013328      0.003895         0.002819        0.002719     0.1
# 20       0.011699      0.003189         0.002416        0.002952     0.5
# 12       0.014131      0.003431         0.002876        0.003837     0.1
# 18       0.009666      0.000819         0.007233        0.003728     0.5
# 38       0.012487      0.003895         0.003620        0.003681     1.5
# 30       0.010072      0.000034         0.004029        0.004222       1
# 22       0.011706      0.003204         0.002417        0.002952     0.7
# 14       0.014096      0.008048         0.003620        0.004479     0.5
# 25       0.018519      0.003219         0.000000        0.000000     0.7
# 19       0.014137      0.004185         0.006033        0.004213     0.5
# 11       0.012875      0.002734         0.005285        0.003547     0.1
# 43       0.014495      0.004669         0.007241        0.003735     1.5
# 27       0.019321      0.000989         0.002821        0.004696     0.7
# 9        0.015310      0.004326         0.004828        0.004327     0.1
# 7        0.014487      0.003888         0.003616        0.003678     0.1
# 6        0.010866      0.000998         0.003622        0.004481     0.1
# 17       0.020562      0.000782         0.000000        0.000000     0.5
# 35       0.020150      0.000021         0.000000        0.000000       1
#
#    param_kernel param_gamma                                       params  \
# 29          rbf        0.01     {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 37          rbf        0.01   {'C': 1.5, 'gamma': 0.01, 'kernel': 'rbf'}
# 21          rbf        0.01   {'C': 0.7, 'gamma': 0.01, 'kernel': 'rbf'}
# 13          rbf        0.01   {'C': 0.5, 'gamma': 0.01, 'kernel': 'rbf'}
# 23          rbf        0.05   {'C': 0.7, 'gamma': 0.05, 'kernel': 'rbf'}
# 39          rbf        0.05   {'C': 1.5, 'gamma': 0.05, 'kernel': 'rbf'}
# 31          rbf        0.05     {'C': 1, 'gamma': 0.05, 'kernel': 'rbf'}
# 15          rbf        0.05   {'C': 0.5, 'gamma': 0.05, 'kernel': 'rbf'}
# 0        linear         NaN               {'C': 0.1, 'kernel': 'linear'}
# 4        linear         NaN               {'C': 1.5, 'kernel': 'linear'}
# 3        linear         NaN                 {'C': 1, 'kernel': 'linear'}
# 2        linear         NaN               {'C': 0.7, 'kernel': 'linear'}
# 1        linear         NaN               {'C': 0.5, 'kernel': 'linear'}
# 41          rbf         0.1    {'C': 1.5, 'gamma': 0.1, 'kernel': 'rbf'}
# 33          rbf         0.1      {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 8          poly        0.05  {'C': 0.1, 'gamma': 0.05, 'kernel': 'poly'}
# 5           rbf        0.01   {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# 16         poly        0.05  {'C': 0.5, 'gamma': 0.05, 'kernel': 'poly'}
# 28         poly         0.5   {'C': 0.7, 'gamma': 0.5, 'kernel': 'poly'}
# 36         poly         0.5     {'C': 1, 'gamma': 0.5, 'kernel': 'poly'}
# 34         poly         0.1     {'C': 1, 'gamma': 0.1, 'kernel': 'poly'}
# 40         poly        0.05  {'C': 1.5, 'gamma': 0.05, 'kernel': 'poly'}
# 42         poly         0.1   {'C': 1.5, 'gamma': 0.1, 'kernel': 'poly'}
# 32         poly        0.05    {'C': 1, 'gamma': 0.05, 'kernel': 'poly'}
# 26         poly         0.1   {'C': 0.7, 'gamma': 0.1, 'kernel': 'poly'}
# 44         poly         0.5   {'C': 1.5, 'gamma': 0.5, 'kernel': 'poly'}
# 24         poly        0.05  {'C': 0.7, 'gamma': 0.05, 'kernel': 'poly'}
# 10         poly         0.1   {'C': 0.1, 'gamma': 0.1, 'kernel': 'poly'}
# 20         poly         0.5   {'C': 0.5, 'gamma': 0.5, 'kernel': 'poly'}
# 12         poly         0.5   {'C': 0.1, 'gamma': 0.5, 'kernel': 'poly'}
# 18         poly         0.1   {'C': 0.5, 'gamma': 0.1, 'kernel': 'poly'}
# 38         poly        0.01  {'C': 1.5, 'gamma': 0.01, 'kernel': 'poly'}
# 30         poly        0.01    {'C': 1, 'gamma': 0.01, 'kernel': 'poly'}
# 22         poly        0.01  {'C': 0.7, 'gamma': 0.01, 'kernel': 'poly'}
# 14         poly        0.01  {'C': 0.5, 'gamma': 0.01, 'kernel': 'poly'}
# 25          rbf         0.1    {'C': 0.7, 'gamma': 0.1, 'kernel': 'rbf'}
# 19          rbf         0.5    {'C': 0.5, 'gamma': 0.5, 'kernel': 'rbf'}
# 11          rbf         0.5    {'C': 0.1, 'gamma': 0.5, 'kernel': 'rbf'}
# 43          rbf         0.5    {'C': 1.5, 'gamma': 0.5, 'kernel': 'rbf'}
# 27          rbf         0.5    {'C': 0.7, 'gamma': 0.5, 'kernel': 'rbf'}
# 9           rbf         0.1    {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}
# 7           rbf        0.05   {'C': 0.1, 'gamma': 0.05, 'kernel': 'rbf'}
# 6          poly        0.01  {'C': 0.1, 'gamma': 0.01, 'kernel': 'poly'}
# 17          rbf         0.1    {'C': 0.5, 'gamma': 0.1, 'kernel': 'rbf'}
# 35          rbf         0.5      {'C': 1, 'gamma': 0.5, 'kernel': 'rbf'}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 29           0.964286           0.964286           1.000000
# 37           0.964286           0.964286           1.000000
# 21           0.964286           0.964286           0.964286
# 13           0.964286           0.964286           0.964286
# 23           0.964286           0.964286           0.964286
# 39           0.964286           0.964286           0.964286
# 31           0.964286           0.964286           0.964286
# 15           0.964286           0.928571           0.964286
# 0            0.964286           0.964286           0.964286
# 4            0.964286           0.928571           0.892857
# 3            0.964286           0.928571           0.892857
# 2            0.964286           0.928571           0.892857
# 1            0.964286           0.928571           0.892857
# 41           0.857143           0.857143           0.892857
# 33           0.821429           0.857143           0.892857
# 8            0.821429           0.892857           0.928571
# 5            0.964286           0.821429           0.821429
# 16           0.821429           0.857143           0.928571
# 28           0.821429           0.857143           0.928571
# 36           0.821429           0.857143           0.928571
# 34           0.821429           0.857143           0.928571
# 40           0.821429           0.857143           0.928571
# 42           0.821429           0.857143           0.928571
# 32           0.821429           0.857143           0.928571
# 26           0.821429           0.857143           0.928571
# 44           0.821429           0.857143           0.928571
# 24           0.821429           0.857143           0.928571
# 10           0.821429           0.857143           0.928571
# 20           0.821429           0.857143           0.928571
# 12           0.821429           0.857143           0.928571
# 18           0.821429           0.857143           0.928571
# 38           0.821429           0.678571           0.642857
# 30           0.821429           0.678571           0.535714
# 22           0.821429           0.642857           0.535714
# 14           0.821429           0.500000           0.535714
# 25           0.500000           0.500000           0.500000
# 19           0.500000           0.500000           0.500000
# 11           0.500000           0.500000           0.500000
# 43           0.500000           0.500000           0.500000
# 27           0.500000           0.500000           0.500000
# 9            0.500000           0.500000           0.500000
# 7            0.500000           0.500000           0.500000
# 6            0.500000           0.500000           0.500000
# 17           0.500000           0.500000           0.500000
# 35           0.500000           0.500000           0.500000
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 29           1.000000           1.000000         0.985714        0.017496
# 37           1.000000           1.000000         0.985714        0.017496
# 21           1.000000           1.000000         0.978571        0.017496
# 13           1.000000           1.000000         0.978571        0.017496
# 23           1.000000           1.000000         0.978571        0.017496
# 39           1.000000           1.000000         0.978571        0.017496
# 31           1.000000           1.000000         0.978571        0.017496
# 15           1.000000           1.000000         0.971429        0.026726
# 0            0.964286           0.928571         0.957143        0.014286
# 4            0.892857           0.928571         0.921429        0.026726
# 3            0.892857           0.928571         0.921429        0.026726
# 2            0.892857           0.928571         0.921429        0.026726
# 1            0.892857           0.928571         0.921429        0.026726
# 41           1.000000           0.964286         0.914286        0.058029
# 33           1.000000           0.964286         0.907143        0.066240
# 8            0.892857           0.857143         0.878571        0.036422
# 5            0.892857           0.857143         0.871429        0.053452
# 16           0.821429           0.821429         0.850000        0.041650
# 28           0.785714           0.821429         0.842857        0.048445
# 36           0.785714           0.821429         0.842857        0.048445
# 34           0.785714           0.821429         0.842857        0.048445
# 40           0.785714           0.821429         0.842857        0.048445
# 42           0.785714           0.821429         0.842857        0.048445
# 32           0.785714           0.821429         0.842857        0.048445
# 26           0.785714           0.821429         0.842857        0.048445
# 44           0.785714           0.821429         0.842857        0.048445
# 24           0.785714           0.821429         0.842857        0.048445
# 10           0.785714           0.821429         0.842857        0.048445
# 20           0.785714           0.821429         0.842857        0.048445
# 12           0.785714           0.821429         0.842857        0.048445
# 18           0.785714           0.821429         0.842857        0.048445
# 38           0.714286           0.678571         0.707143        0.061445
# 30           0.642857           0.678571         0.671429        0.091473
# 22           0.571429           0.678571         0.650000        0.099488
# 14           0.535714           0.607143         0.600000        0.116058
# 25           0.535714           0.535714         0.514286        0.017496
# 19           0.535714           0.535714         0.514286        0.017496
# 11           0.535714           0.535714         0.514286        0.017496
# 43           0.535714           0.535714         0.514286        0.017496
# 27           0.535714           0.535714         0.514286        0.017496
# 9            0.535714           0.535714         0.514286        0.017496
# 7            0.535714           0.535714         0.514286        0.017496
# 6            0.535714           0.535714         0.514286        0.017496
# 17           0.535714           0.535714         0.514286        0.017496
# 35           0.535714           0.535714         0.514286        0.017496
#
#     rank_test_score
# 29                1
# 37                1
# 21                3
# 13                3
# 23                3
# 39                3
# 31                3
# 15                8
# 0                 9
# 4                10
# 3                10
# 2                10
# 1                10
# 41               14
# 33               15
# 8                16
# 5                17
# 16               18
# 28               19
# 36               19
# 34               19
# 40               19
# 42               19
# 32               19
# 26               19
# 44               19
# 24               19
# 10               19
# 20               19
# 12               19
# 18               19
# 38               32
# 30               33
# 22               34
# 14               35
# 25               36
# 19               36
# 11               36
# 43               36
# 27               36
# 9                36
# 7                36
# 6                36
# 17               36
# 35               36

# %% [markdown]
# **Setting the best parameters to a new classifier for comparison**

# %%
classifier_svm_tune = SVC(C= 1,kernel = 'rbf',gamma= 0.01,probability=True)
classifier_svm_tune.fit(X_train, y_train)
# Out:
# SVC(C=1, gamma=0.01, probability=True)

# %%
print(f"accuracy of SVM after hyper-parameter tuning {classifier_svm_tune.score(X_test, y_test)}")
plot_confusion_matrix(classifier_svm_tune,
                      X_test,
                      y_test,
                      display_labels=['Faulty','Fine']
                      
                     )
plt.grid(False)
plt.show()
# Out:
# accuracy of SVM after hyper-parameter tuning 0.9833333333333333

# %%
y_pred = classifier_svm_tune.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#         -1.0       0.97      1.00      0.98        28
#          1.0       1.00      0.97      0.98        32
#
#     accuracy                           0.98        60
#    macro avg       0.98      0.98      0.98        60
# weighted avg       0.98      0.98      0.98        60

# %%
# Examine ROC curve and AUC.
y_hat_proba = classifier_svm_tune.predict_proba(X_test)
svm_fpr, svm_tpr, thresholds2 = roc_curve(y_test, y_hat_proba[:,1])
svm_auc = auc(svm_fpr, svm_tpr)
fig = plt.figure(figsize=(12,7))
ax1 = fig.add_subplot(111)
ax1.fill_between(svm_fpr, svm_tpr, 0, color='Olive', alpha=0.6)
ax1 = plt.plot(svm_fpr, svm_tpr, linewidth=3, label='SVM ROC curve ; AUC = %0.2f' % svm_auc)
plt.legend(loc='upper left')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('SVM ROC Curve after hyper-parameter tuning', size=14)
# Out:
# Text(0.5, 1.0, 'SVM ROC Curve after hyper-parameter tuning')

# %% [markdown]
# ### **KNN (K Nearest Neighbour)**

# %%
classifier_knn = KNeighborsClassifier()
classifier_knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# Accuracy
print(f"accuracy of KNN before hyper-parameter tuning {classifier_knn.score(X_test, y_test)}")
# Confusuion Matrix
plot_confusion_matrix(classifier_knn,
                      X_test,
                      y_test,
                      display_labels=['Faulty','Fine']
                     )
plt.grid(False)
plt.show()
# classification Report
y_pred = classifier_knn.predict(X_test)
print(classification_report(y_test, y_pred))
# ROC curve and AUC.


y_hat_proba = classifier_knn.predict_proba(X_test)
fpr, tpr, thresholds2 = roc_curve(y_test, y_hat_proba[:,1])
knn_auc = auc(fpr, tpr)
fig = plt.figure(figsize=(12,7))
ax1 = fig.add_subplot(111)
ax1.fill_between(fpr, tpr, 0, color='Olive', alpha=0.6)
ax1 = plt.plot(fpr, tpr, linewidth=3, label='KNN ROC curve ; AUC = %0.2f' % knn_auc)
plt.legend(loc='upper left')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('KNN ROC Curve before hyper-parameter tuning', size=14)
# Out:
# accuracy of KNN before hyper-parameter tuning 0.95
#               precision    recall  f1-score   support
#
#         -1.0       1.00      0.89      0.94        28
#          1.0       0.91      1.00      0.96        32
#
#     accuracy                           0.95        60
#    macro avg       0.96      0.95      0.95        60
# weighted avg       0.95      0.95      0.95        60
# Text(0.5, 1.0, 'KNN ROC Curve before hyper-parameter tuning')

# %% [markdown]
# **Hyper-parameter tuning for KNN using GridSearchCV**

# %%
k_range = list(range(1, 31))
parameters = dict(n_neighbors=k_range)

# %%
grid_search = GridSearchCV(estimator = classifier_knn,
                           param_grid = parameters,
                           scoring = 'accuracy',
                           cv = 5,
                           n_jobs = -1)
grid_search = grid_search.fit(X_train, y_train)

# %%
print("Best Score using Grid Search:",grid_search.best_score_)
print("Best Parameters using Grid Search:", grid_search.best_params_)
# Out:
# Best Score using Grid Search: 0.9714285714285715
# Best Parameters using Grid Search: {'n_neighbors': 2}

# %%
cv_results=pd.DataFrame(grid_search.cv_results_)
cv_results=cv_results.sort_values(by='rank_test_score')
cv_results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 1        0.000000      0.000000         0.012501        0.006250
# 9        0.003125      0.006249         0.004428        0.006144
# 7        0.003125      0.006250         0.006250        0.007655
# 11       0.000000      0.000000         0.009374        0.007654
# 3        0.000000      0.000000         0.006253        0.007659
# 5        0.000000      0.000000         0.006250        0.007655
# 6        0.006250      0.007655         0.006250        0.007655
# 13       0.003125      0.006250         0.006250        0.007654
# 2        0.007552      0.007007         0.005728        0.005741
# 4        0.006251      0.007656         0.006249        0.007654
# 10       0.004428      0.006144         0.006251        0.007656
# 15       0.006252      0.007657         0.004427        0.006140
# 0        0.000000      0.000000         0.024998        0.012499
# 19       0.007552      0.007006         0.003125        0.006250
# 14       0.004427      0.006140         0.003127        0.006254
# 12       0.004427      0.006140         0.009376        0.007656
# 8        0.004426      0.006140         0.007553        0.007009
# 16       0.003125      0.006250         0.006250        0.007654
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 1            0.964286         0.971429        0.014286                1
# 9            1.000000         0.971429        0.026726                1
# 7            1.000000         0.964286        0.022588                3
# 11           1.000000         0.957143        0.034993                4
# 3            0.964286         0.957143        0.026726                5
# 5            0.964286         0.957143        0.014286                5
# 6            0.964286         0.957143        0.014286                5
# 13           0.964286         0.957143        0.034993                5
# 2            0.928571         0.950000        0.028571                9
# 4            0.928571         0.950000        0.028571                9
# 10           1.000000         0.950000        0.036422                9
# 15           0.964286         0.950000        0.017496                9
# 0            0.928571         0.935714        0.041650               13
# 19           0.964286         0.935714        0.052489               13
# 14           0.964286         0.935714        0.034993               13
# 12           0.964286         0.935714        0.034993               13
# 8            0.892857         0.935714        0.034993               13
# 16           0.964286         0.928571        0.045175               18
# 17           0.964286         0.928571        0.045175               18
# 20           0.964286         0.921429        0.057143               20
# 21           0.964286         0.921429        0.057143               20
# 23           0.964286         0.921429        0.057143               20
# 22           0.964286         0.914286        0.066240               23
# 18           0.964286         0.907143        0.058029               24
# 25           0.964286         0.907143        0.048445               24
# 27           0.964286         0.907143        0.048445               24
# 29           0.964286         0.907143        0.048445               24
# 24           0.928571         0.900000        0.041650               28
# 26           0.928571         0.900000        0.041650               28
# 28           0.928571         0.900000        0.041650               28

# %% [markdown]
# **Setting the best parameters to a new classifier for comparison**

# %%
classifier_knn_tune = KNeighborsClassifier(n_neighbors=2)
classifier_knn_tune.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
# Accuracy
print(f"accuracy of KNN after hyper-parameter tuning {classifier_knn_tune.score(X_test, y_test)}")
# Confusuion Matrix
plot_confusion_matrix(classifier_knn_tune,
                      X_test,
                      y_test,
                      display_labels=['Faulty','Fine']
                     )
plt.grid(False)
plt.show()
# classification Report
y_pred = classifier_knn_tune.predict(X_test)
print(classification_report(y_test, y_pred))
# ROC curve and AUC.
y_hat_proba = classifier_knn_tune.predict_proba(X_test)
fpr, tpr, thresholds2 = roc_curve(y_test, y_hat_proba[:,1])
auc1 = auc(fpr, tpr)
fig = plt.figure(figsize=(12,7))
ax1 = fig.add_subplot(111)
ax1.fill_between(fpr, tpr, 0, color='Olive', alpha=0.6)
ax1 = plt.plot(fpr, tpr, linewidth=3, label='KNN ROC curve ; AUC = %0.2f' % auc1)
plt.legend(loc='upper left')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('KNN ROC Curve after hyper-parameter tuning', size=14)
# Out:
# accuracy of KNN after hyper-parameter tuning 0.95
#               precision    recall  f1-score   support
#
#         -1.0       0.90      1.00      0.95        28
#          1.0       1.00      0.91      0.95        32
#
#     accuracy                           0.95        60
#    macro avg       0.95      0.95      0.95        60
# weighted avg       0.95      0.95      0.95        60
# Text(0.5, 1.0, 'KNN ROC Curve after hyper-parameter tuning')

# %% [markdown]
# ### **Decision Tree Classifier**

# %%
classifier_dt=DecisionTreeClassifier()
classifier_dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Accuracy
print(f"accuracy of Decision Tree before hyper-parameter tuning {classifier_dt.score(X_test, y_test)}")
# Confusuion Matrix
plot_confusion_matrix(classifier_dt,
                      X_test,
                      y_test,
                      display_labels=['Faulty','Fine']
                     )
plt.grid(False)
plt.show()
# classification Report
y_pred = classifier_dt.predict(X_test)
print(classification_report(y_test, y_pred))
# ROC curve and AUC.
y_hat_proba = classifier_dt.predict_proba(X_test)
fpr, tpr, thresholds2 = roc_curve(y_test, y_hat_proba[:,1])
auc_dt = auc(fpr, tpr)
fig = plt.figure(figsize=(12,7))
ax1 = fig.add_subplot(111)
ax1.fill_between(fpr, tpr, 0, color='Olive', alpha=0.6)
ax1 = plt.plot(fpr, tpr, linewidth=3, label='Decision Tree ROC curve ; AUC = %0.2f' % auc_dt)
plt.legend(loc='upper left')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Decision Tree ROC Curve before hyper-parameter tuning', size=14)
# Out:
# accuracy of Decision Tree before hyper-parameter tuning 0.8
#               precision    recall  f1-score   support
#
#         -1.0       0.75      0.86      0.80        28
#          1.0       0.86      0.75      0.80        32
#
#     accuracy                           0.80        60
#    macro avg       0.80      0.80      0.80        60
# weighted avg       0.81      0.80      0.80        60
# Text(0.5, 1.0, 'Decision Tree ROC Curve before hyper-parameter tuning')

# %% [markdown]
# **Hyper-parameter tuning for Decision Tree using GridSearchCV**

# %%
parameters={'criterion':["gini",'entropy']
    ,"max_depth":[10, 20, 30, 40, 50, 70,None]}
    
grid_search = GridSearchCV(estimator = classifier_dt,
                           param_grid = parameters,
                           scoring = 'accuracy',
                           cv = 5,
                           n_jobs = -1)
grid_search = grid_search.fit(X_train, y_train)

# %%
print("Best Score using Grid Search:",grid_search.best_score_)
print("Best Parameters using Grid Search:", grid_search.best_params_)
# Out:
# Best Score using Grid Search: 0.8571428571428571
# Best Parameters using Grid Search: {'criterion': 'entropy', 'max_depth': 40}

# %%
max_depth=grid_search.best_params_['max_depth']
criterion=grid_search.best_params_['criterion']

# %%
cv_results=pd.DataFrame(grid_search.cv_results_)
cv_results=cv_results.sort_values(by='rank_test_score')
cv_results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 10       0.009374      0.007654         0.003125        0.006251
# 13       0.009374      0.007654         0.003124        0.006249
# 7        0.007554      0.009477         0.006250        0.007654
# 8        0.012500      0.006250         0.000000        0.000000
# 11       0.007555      0.007011         0.003127        0.006253
# 2        0.003125      0.006249         0.003125        0.006249
# 3        0.006250      0.007654         0.003125        0.006251
# 9        0.009375      0.007654         0.006248        0.007653
# 12       0.012499      0.006249         0.003125        0.006250
# 5        0.007554      0.007009         0.004427        0.006141
# 6        0.007554      0.007009         0.003127        0.006253
# 0        0.011979      0.004466         0.001302        0.002604
# 1        0.000000      0.000000         0.009378        0.007657
# 4        0.009375      0.007655         0.000000        0.000000
#
#    param_criterion param_max_depth  \
# 10         entropy              40
# 13         entropy            None
# 7          entropy              10
# 8          entropy              20
# 11         entropy              50
# 2             gini              30
# 3             gini              40
# 9          entropy              30
# 12         entropy              70
# 5             gini              70
# 6             gini            None
# 0             gini              10
# 1             gini              20
# 4             gini              50
#
#                                          params  split0_test_score  \
# 10    {'criterion': 'entropy', 'max_depth': 40}           0.857143
# 13  {'criterion': 'entropy', 'max_depth': None}           0.857143
# 7     {'criterion': 'entropy', 'max_depth': 10}           0.857143
# 8     {'criterion': 'entropy', 'max_depth': 20}           0.821429
# 11    {'criterion': 'entropy', 'max_depth': 50}           0.821429
# 2        {'criterion': 'gini', 'max_depth': 30}           0.928571
# 3        {'criterion': 'gini', 'max_depth': 40}           0.928571
# 9     {'criterion': 'entropy', 'max_depth': 30}           0.857143
# 12    {'criterion': 'entropy', 'max_depth': 70}           0.821429
# 5        {'criterion': 'gini', 'max_depth': 70}           0.928571
# 6      {'criterion': 'gini', 'max_depth': None}           0.892857
# 0        {'criterion': 'gini', 'max_depth': 10}           0.928571
# 1        {'criterion': 'gini', 'max_depth': 20}           0.892857
# 4        {'criterion': 'gini', 'max_depth': 50}           0.892857
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 10           0.892857           0.821429           0.964286
# 13           0.857143           0.857143           0.892857
# 7            0.821429           0.857143           0.928571
# 8            0.857143           0.857143           0.928571
# 11           0.892857           0.857143           0.892857
# 2            0.928571           0.678571           0.857143
# 3            0.928571           0.678571           0.857143
# 9            0.785714           0.857143           0.928571
# 12           0.821429           0.857143           0.928571
# 5            0.928571           0.678571           0.785714
# 6            0.928571           0.678571           0.857143
# 0            0.892857           0.678571           0.857143
# 1            0.892857           0.678571           0.892857
# 4            0.892857           0.678571           0.857143
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 10           0.750000         0.857143        0.071429                1
# 13           0.785714         0.850000        0.034993                2
# 7            0.750000         0.842857        0.058029                3
# 8            0.750000         0.842857        0.058029                3
# 11           0.750000         0.842857        0.053452                3
# 2            0.785714         0.835714        0.094761                6
# 3            0.785714         0.835714        0.094761                6
# 9            0.750000         0.835714        0.062270                6
# 12           0.750000         0.835714        0.058029                6
# 5            0.821429         0.828571        0.094221               10
# 6            0.750000         0.821429        0.093131               11
# 0            0.714286         0.814286        0.099488               12
# 1            0.714286         0.814286        0.096890               12
# 4            0.714286         0.807143        0.092029               14

# %% [markdown]
# **Setting the best parameters to a new classifier for comparison**

# %%
classifier_dt_tune = DecisionTreeClassifier(criterion= criterion, max_depth= max_depth)
classifier_dt_tune.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=40)

# %%
# Accuracy
print(f"accuracy of Decision Tree after hyper-parameter tuning {classifier_dt_tune.score(X_test, y_test)}")
# Confusuion Matrix
plot_confusion_matrix(classifier_dt_tune,
                      X_test,
                      y_test,
                      display_labels=['Faulty','Fine']
                     )
plt.grid(False)
plt.show()
# classification Report
y_pred = classifier_dt_tune.predict(X_test)
print(classification_report(y_test, y_pred))
# ROC curve and AUC.
y_hat_proba = classifier_dt_tune.predict_proba(X_test)
fpr, tpr, thresholds2 = roc_curve(y_test, y_hat_proba[:,1])
auc_dt = auc(fpr, tpr)
fig = plt.figure(figsize=(12,7))
ax1 = fig.add_subplot(111)
ax1.fill_between(fpr, tpr, 0, color='Olive', alpha=0.6)
ax1 = plt.plot(fpr, tpr, linewidth=3, label='Decision Tree ROC curve ; AUC = %0.2f' % auc_dt)
plt.legend(loc='upper left')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Decision Tree ROC Curve after hyper-parameter tuning', size=14)
# Out:
# accuracy of Decision Tree after hyper-parameter tuning 0.9
#               precision    recall  f1-score   support
#
#         -1.0       0.89      0.89      0.89        28
#          1.0       0.91      0.91      0.91        32
#
#     accuracy                           0.90        60
#    macro avg       0.90      0.90      0.90        60
# weighted avg       0.90      0.90      0.90        60
# Text(0.5, 1.0, 'Decision Tree ROC Curve after hyper-parameter tuning')

# %% [markdown]
# ### **Random Forest**

# %%
classifier_rf = RandomForestClassifier()
classifier_rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
# Accuracy
print(f"accuracy of Random Forest before hyper-parameter tuning {classifier_rf.score(X_test, y_test)}")
# Confusuion Matrix
plot_confusion_matrix(classifier_rf,
                      X_test,
                      y_test,
                      display_labels=['Faulty','Fine']
                     )
plt.grid(False)
plt.show()
# classification Report
y_pred = classifier_rf.predict(X_test)
print(classification_report(y_test, y_pred))
# ROC curve and AUC.
y_hat_proba = classifier_rf.predict_proba(X_test)
fpr, tpr, thresholds2 = roc_curve(y_test, y_hat_proba[:,1])
auc_rf = auc(fpr, tpr)
fig = plt.figure(figsize=(12,7))
ax1 = fig.add_subplot(111)
ax1.fill_between(fpr, tpr, 0, color='Olive', alpha=0.6)
ax1 = plt.plot(fpr, tpr, linewidth=3, label='Random Forest ROC curve ; AUC = %0.2f' % auc_rf)
plt.legend(loc='upper left')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Random Forest ROC Curve before hyper-parameter tuning', size=14)
# Out:
# accuracy of Random Forest before hyper-parameter tuning 0.9666666666666667
#               precision    recall  f1-score   support
#
#         -1.0       0.93      1.00      0.97        28
#          1.0       1.00      0.94      0.97        32
#
#     accuracy                           0.97        60
#    macro avg       0.97      0.97      0.97        60
# weighted avg       0.97      0.97      0.97        60
# Text(0.5, 1.0, 'Random Forest ROC Curve before hyper-parameter tuning')

# %% [markdown]
#  **Hyper-parameter tuning for Random Forest using GridSearchCV**

# %%
n_estimators = [70,100,150,220,250]
max_depth= [20, 40, 50]

parameters = {'n_estimators': n_estimators,
              'max_depth': max_depth}
    
grid_search = GridSearchCV(estimator = classifier_rf,
                           param_grid = parameters,
                           scoring = 'accuracy',
                           cv = 5,
                           n_jobs = -1)
grid_search = grid_search.fit(X_train, y_train)

# %%
print("Best Score using Grid Search:",grid_search.best_score_)
print("Best Parameters using Grid Search:", grid_search.best_params_)
# Out:
# Best Score using Grid Search: 0.9714285714285715
# Best Parameters using Grid Search: {'max_depth': 20, 'n_estimators': 100}

# %%
cv_results=pd.DataFrame(grid_search.cv_results_)
cv_results=cv_results.sort_values(by='rank_test_score')
cv_results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 1        0.275490      0.004822         0.020527        0.000813
# 2        0.402838      0.005723         0.032214        0.004022
# 8        0.597302      0.012309         0.042266        0.005097
# 11       0.268440      0.008515         0.021735        0.003221
# 3        0.587203      0.010426         0.042667        0.003899
# 4        0.660918      0.008445         0.049500        0.000975
# 6        0.266801      0.005193         0.020515        0.005145
# 7        0.396823      0.007468         0.028988        0.003509
# 12       0.398453      0.004886         0.030227        0.000067
# 13       0.587845      0.005048         0.040251        0.000006
# 14       0.639711      0.060234         0.038330        0.011478
# 0        0.205411      0.007916         0.020120        0.006356
# 5        0.184759      0.004461         0.018920        0.003507
# 9        0.694294      0.023636         0.042678        0.003940
# 10       0.186374      0.003925         0.013679        0.004479
#
#    param_max_depth param_n_estimators                                  params  \
# 1               20                100  {'max_depth': 20, 'n_estimators': 100}
# 2               20                150  {'max_depth': 20, 'n_estimators': 150}
# 8               40                220  {'max_depth': 40, 'n_estimators': 220}
# 11              50                100  {'max_depth': 50, 'n_estimators': 100}
# 3               20                220  {'max_depth': 20, 'n_estimators': 220}
# 4               20                250  {'max_depth': 20, 'n_estimators': 250}
# 6               40                100  {'max_depth': 40, 'n_estimators': 100}
# 7               40                150  {'max_depth': 40, 'n_estimators': 150}
# 12              50                150  {'max_depth': 50, 'n_estimators': 150}
# 13              50                220  {'max_depth': 50, 'n_estimators': 220}
# 14              50                250  {'max_depth': 50, 'n_estimators': 250}
# 0               20                 70   {'max_depth': 20, 'n_estimators': 70}
# 5               40                 70   {'max_depth': 40, 'n_estimators': 70}
# 9               40                250  {'max_depth': 40, 'n_estimators': 250}
# 10              50                 70   {'max_depth': 50, 'n_estimators': 70}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 1            0.964286           0.928571           0.964286
# 2            0.964286           0.928571           0.964286
# 8            0.964286           0.928571           0.964286
# 11           0.964286           0.964286           0.964286
# 3            0.964286           0.928571           0.964286
# 4            0.964286           0.928571           0.964286
# 6            0.964286           0.928571           0.928571
# 7            0.964286           0.928571           0.964286
# 12           0.964286           0.928571           0.964286
# 13           0.964286           0.928571           0.964286
# 14           0.964286           0.928571           0.964286
# 0            0.964286           0.928571           0.964286
# 5            0.964286           0.928571           0.928571
# 9            0.964286           0.928571           0.964286
# 10           0.964286           0.892857           0.928571
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 1            1.000000           1.000000         0.971429        0.026726
# 2            1.000000           1.000000         0.971429        0.026726
# 8            1.000000           1.000000         0.971429        0.026726
# 11           0.964286           1.000000         0.971429        0.014286
# 3            0.964286           1.000000         0.964286        0.022588
# 4            0.964286           1.000000         0.964286        0.022588
# 6            1.000000           1.000000         0.964286        0.031944
# 7            0.964286           1.000000         0.964286        0.022588
# 12           0.964286           1.000000         0.964286        0.022588
# 13           0.964286           1.000000         0.964286        0.022588
# 14           0.964286           1.000000         0.964286        0.022588
# 0            0.928571           1.000000         0.957143        0.026726
# 5            0.964286           1.000000         0.957143        0.026726
# 9            0.964286           0.964286         0.957143        0.014286
# 10           0.964286           1.000000         0.950000        0.036422
#
#     rank_test_score
# 1                 1
# 2                 1
# 8                 1
# 11                1
# 3                 5
# 4                 5
# 6                 5
# 7                 5
# 12                5
# 13                5
# 14                5
# 0                12
# 5                12
# 9                12
# 10               15

# %% [markdown]
# **Setting the best parameters to a new classifier for comparison**

# %%
classifier_rf_tune =RandomForestClassifier(max_depth= grid_search.best_params_['max_depth'], n_estimators= grid_search.best_params_['n_estimators'])
classifier_rf_tune.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=20)

# %%
# Accuracy
print(f"accuracy of Random Forest after hyper-parameter tuning {classifier_rf_tune.score(X_test, y_test)}")
# Confusuion Matrix
plot_confusion_matrix(classifier_rf_tune,
                      X_test,
                      y_test,
                      display_labels=['Faulty','Fine']
                     )
plt.grid(False)
plt.show()
# classification Report
y_pred = classifier_rf_tune.predict(X_test)
print(classification_report(y_test, y_pred))
# ROC curve and AUC.
y_hat_proba = classifier_rf_tune.predict_proba(X_test)
fpr, tpr, thresholds2 = roc_curve(y_test, y_hat_proba[:,1])
auc_rf = auc(fpr, tpr)
fig = plt.figure(figsize=(12,7))
ax1 = fig.add_subplot(111)
ax1.fill_between(fpr, tpr, 0, color='Olive', alpha=0.6)
ax1 = plt.plot(fpr, tpr, linewidth=3, label='Random Forest ROC curve ; AUC = %0.2f' % auc_rf)
plt.legend(loc='upper left')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Random Forest ROC Curve after hyper-parameter tuning', size=14)
# Out:
# accuracy of Random Forest after hyper-parameter tuning 0.9833333333333333
#               precision    recall  f1-score   support
#
#         -1.0       0.97      1.00      0.98        28
#          1.0       1.00      0.97      0.98        32
#
#     accuracy                           0.98        60
#    macro avg       0.98      0.98      0.98        60
# weighted avg       0.98      0.98      0.98        60
# Text(0.5, 1.0, 'Random Forest ROC Curve after hyper-parameter tuning')

# %% [markdown]
# ### **Conclusion**

# %% [markdown]
# Among the 4 models, we get improvement after hyper-parameter tuning on the two following models:
# * Decision Tree (from 80% to 90%)
# * Random Forest (from 96% to 98%)
#
#
# On the other hand, the following two models did not show improvement after hyper-parameter tuning:
# * SVM (98%)
# * K-Nearest Neighbor (95%)
#
# Therefore we observe that Random Forest is outperforming all other models.
